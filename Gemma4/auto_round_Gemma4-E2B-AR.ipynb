# %%
# !pip install --upgrade transformers --break-system-packages

# %%
# !pip install auto-round --break-system-packages

# %%
import os
import torch
from auto_round import AutoRound
from huggingface_hub import HfApi, create_repo, notebook_login, get_token
from transformers import AutoModelForImageTextToText, AutoProcessor
from safetensors import safe_open
import safetensors.torch as st
import gc
import json

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Version: {torch.version.cuda}")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
# Out:
# PyTorch Version: 2.11.0+cu128
# CUDA Available: True
# CUDA Version: 12.8
# GPU Name: NVIDIA L40S
# VRAM: 44.5 GB

# %%
notebook_login()

# %%
MODEL_ID = "google/gemma-4-E2B-it"
HF_USER = "Vishva007"
OUTPUT_BASE_DIR = "./AutoRound-e2b-AR"
LOCAL_PATH = "./local_model-e2b-AR"

# %%
# !hf download $MODEL_ID --local-dir $LOCAL_PATH
# Out:
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 9 files:   0%|                                  | 0/9 [00:00<?, ?it/s]Still waiting to acquire lock on /workspace/local_model-e2b-AR/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /workspace/local_model-e2b-AR/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /workspace/local_model-e2b-AR/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /workspace/local_model-e2b-AR/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Still waiting to acquire lock on /workspace/local_model-e2b-AR/.cache/huggingface/.gitignore.lock (elapsed: 0.1 seconds)
# Downloading (incomplete total...):   0%| | 24.1k/10.3G [00:00<22:11:30, 129kB/s
# Downloading (incomplete total...): 100%|███| 10.3G/10.3G [00:16<00:00, 588MB/s]
# Fetching 9 files: 100%|██████████████████████████| 9/9 [00:16<00:00,  1.81s/it]
# Download complete: 100%|███████████████████| 10.3G/10.3G [00:16<00:00, 588MB/s]✓ Downloaded
#   path: /workspace/local_model-e2b-AR
# Download complete: 100%|███████████████████| 10.3G/10.3G [00:16<00:00, 629MB/s]

# %%
model = AutoModelForImageTextToText.from_pretrained(
    LOCAL_PATH, 
    dtype=torch.bfloat16,
    device_map="auto"
)
processor = AutoProcessor.from_pretrained(LOCAL_PATH)

tokenizer = processor.tokenizer
# Out:
# Loading weights:   0%|          | 0/1951 [00:00<?, ?it/s]

# %%
model
# Out:
# Gemma4ForConditionalGeneration(
#   (model): Gemma4Model(
#     (vision_tower): Gemma4VisionModel(
#       (patch_embedder): Gemma4VisionPatchEmbedder(
#         (input_proj): Linear(in_features=768, out_features=768, bias=False)
#       )
#       (encoder): Gemma4VisionEncoder(
#         (rotary_emb): Gemma4VisionRotaryEmbedding()
#         (layers): ModuleList(
#           (0-15): 16 x Gemma4VisionEncoderLayer(
#             (self_attn): Gemma4VisionAttention(
#               (q_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=768, out_features=768, bias=False)
#               )
#               (k_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=768, out_features=768, bias=False)
#               )
#               (v_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=768, out_features=768, bias=False)
#               )
#               (o_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=768, out_features=768, bias=False)
#               )
#               (q_norm): Gemma4RMSNorm()
#               (k_norm): Gemma4RMSNorm()
#               (v_norm): Gemma4RMSNorm()
#             )
#             (mlp): Gemma4VisionMLP(
#               (gate_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=768, out_features=3072, bias=False)
#               )
#               (up_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=768, out_features=3072, bias=False)
#               )
#               (down_proj): Gemma4ClippableLinear(
#                 (linear): Linear(in_features=3072, out_features=768, bias=False)
#               )
#               (act_fn): GELUTanh()
#             )
#             (input_layernorm): Gemma4RMSNorm()
#             (post_attention_layernorm): Gemma4RMSNorm()
#             (pre_feedforward_layernorm): Gemma4RMSNorm()
#             (post_feedforward_layernorm): Gemma4RMSNorm()
#           )
#         )
#       )
#       (pooler): Gemma4VisionPooler()
#     )
#     (language_model): Gemma4TextModel(
#       (embed_tokens): Gemma4TextScaledWordEmbedding(262144, 1536, padding_idx=0)
#       (layers): ModuleList(
#         (0-3): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (k_norm): Gemma4RMSNorm()
#             (v_norm): Gemma4RMSNorm()
#             (k_proj): Linear(in_features=1536, out_features=256, bias=False)
#             (v_proj): Linear(in_features=1536, out_features=256, bias=False)
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (down_proj): Linear(in_features=6144, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (4): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (k_norm): Gemma4RMSNorm()
#             (v_norm): Gemma4RMSNorm()
#             (k_proj): Linear(in_features=1536, out_features=512, bias=False)
#             (v_proj): Linear(in_features=1536, out_features=512, bias=False)
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (down_proj): Linear(in_features=6144, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (5-8): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (k_norm): Gemma4RMSNorm()
#             (v_norm): Gemma4RMSNorm()
#             (k_proj): Linear(in_features=1536, out_features=256, bias=False)
#             (v_proj): Linear(in_features=1536, out_features=256, bias=False)
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (down_proj): Linear(in_features=6144, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (9): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (k_norm): Gemma4RMSNorm()
#             (v_norm): Gemma4RMSNorm()
#             (k_proj): Linear(in_features=1536, out_features=512, bias=False)
#             (v_proj): Linear(in_features=1536, out_features=512, bias=False)
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (down_proj): Linear(in_features=6144, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (10-13): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (k_norm): Gemma4RMSNorm()
#             (v_norm): Gemma4RMSNorm()
#             (k_proj): Linear(in_features=1536, out_features=256, bias=False)
#             (v_proj): Linear(in_features=1536, out_features=256, bias=False)
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (down_proj): Linear(in_features=6144, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (14): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (k_norm): Gemma4RMSNorm()
#             (v_norm): Gemma4RMSNorm()
#             (k_proj): Linear(in_features=1536, out_features=512, bias=False)
#             (v_proj): Linear(in_features=1536, out_features=512, bias=False)
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=6144, bias=False)
#             (down_proj): Linear(in_features=6144, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (15-18): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (19): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (20-23): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (24): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (25-28): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (29): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (30-33): 4 x Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=2048, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=2048, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#         (34): Gemma4TextDecoderLayer(
#           (self_attn): Gemma4TextAttention(
#             (q_proj): Linear(in_features=1536, out_features=4096, bias=False)
#             (q_norm): Gemma4RMSNorm()
#             (o_proj): Linear(in_features=4096, out_features=1536, bias=False)
#           )
#           (mlp): Gemma4TextMLP(
#             (gate_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (up_proj): Linear(in_features=1536, out_features=12288, bias=False)
#             (down_proj): Linear(in_features=12288, out_features=1536, bias=False)
#             (act_fn): GELUTanh()
#           )
#           (input_layernorm): Gemma4RMSNorm()
#           (post_attention_layernorm): Gemma4RMSNorm()
#           (pre_feedforward_layernorm): Gemma4RMSNorm()
#           (post_feedforward_layernorm): Gemma4RMSNorm()
#           (act_fn): GELUTanh()
#           (per_layer_input_gate): Linear(in_features=1536, out_features=256, bias=False)
#           (per_layer_projection): Linear(in_features=256, out_features=1536, bias=False)
#           (post_per_layer_input_norm): Gemma4RMSNorm()
#         )
#       )
#       (norm): Gemma4RMSNorm()
#       (rotary_emb): Gemma4TextRotaryEmbedding()
#       (embed_tokens_per_layer): Gemma4TextScaledWordEmbedding(262144, 8960, padding_idx=0)
#       (per_layer_model_projection): Linear(in_features=1536, out_features=8960, bias=False)
#       (per_layer_projection_norm): Gemma4RMSNorm()
#     )
#     (audio_tower): Gemma4AudioModel(
#       (subsample_conv_projection): Gemma4AudioSubSampleConvProjection(
#         (layer0): Gemma4AudioSubSampleConvProjectionLayer(
#           (conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (norm): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#           (act): ReLU()
#         )
#         (layer1): Gemma4AudioSubSampleConvProjectionLayer(
#           (conv): Conv2d(128, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (norm): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#           (act): ReLU()
#         )
#         (input_proj_linear): Linear(in_features=1024, out_features=1024, bias=False)
#       )
#       (rel_pos_enc): Gemma4AudioRelPositionalEncoding()
#       (layers): ModuleList(
#         (0-11): 12 x Gemma4AudioLayer(
#           (feed_forward1): Gemma4AudioFeedForward(
#             (ffw_layer_1): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=4096, bias=False)
#             )
#             (ffw_layer_2): Gemma4ClippableLinear(
#               (linear): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (pre_layer_norm): Gemma4RMSNorm()
#             (post_layer_norm): Gemma4RMSNorm()
#             (act_fn): SiLUActivation()
#           )
#           (feed_forward2): Gemma4AudioFeedForward(
#             (ffw_layer_1): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=4096, bias=False)
#             )
#             (ffw_layer_2): Gemma4ClippableLinear(
#               (linear): Linear(in_features=4096, out_features=1024, bias=False)
#             )
#             (pre_layer_norm): Gemma4RMSNorm()
#             (post_layer_norm): Gemma4RMSNorm()
#             (act_fn): SiLUActivation()
#           )
#           (self_attn): Gemma4AudioAttention(
#             (q_proj): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (k_proj): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (v_proj): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (post): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (relative_k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           )
#           (lconv1d): Gemma4AudioLightConv1d(
#             (linear_start): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=2048, bias=False)
#             )
#             (linear_end): Gemma4ClippableLinear(
#               (linear): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (depthwise_conv1d): Gemma4AudioCausalConv1d(1024, 1024, kernel_size=(5,), stride=(1,), groups=1024, bias=False)
#             (pre_layer_norm): Gemma4RMSNorm()
#             (conv_norm): Gemma4RMSNorm()
#             (act_fn): SiLUActivation()
#           )
#           (norm_pre_attn): Gemma4RMSNorm()
#           (norm_post_attn): Gemma4RMSNorm()
#           (norm_out): Gemma4RMSNorm()
#         )
#       )
#       (output_proj): Linear(in_features=1024, out_features=1536, bias=True)
#     )
#     (embed_vision): Gemma4MultimodalEmbedder(
#       (embedding_projection): Linear(in_features=768, out_features=1536, bias=False)
#       (embedding_pre_projection_norm): Gemma4RMSNorm()
#     )
#     (embed_audio): Gemma4MultimodalEmbedder(
#       (embedding_projection): Linear(in_features=1536, out_features=1536, bias=False)
#       (embedding_pre_projection_norm): Gemma4RMSNorm()
#     )
#   )
#   (lm_head): Linear(in_features=1536, out_features=262144, bias=False)
# )

# %%
# layer_config = {}
# for name, _ in model.named_modules():
#     if name.startswith(("model.vision_tower", "model.audio_tower",
#                         "model.multi_modal_projector", "model.audio_projector")):
#         layer_config[name] = {"bits": 32}

# print(f"Skipping {len(layer_config)} non-LM modules")

# %%
TUNING_CONFIG = {
    "group_size": 128,
    "sym": True,
    "iters": 800,  # High accuracy (Production grade)
    "nsamples": 512,  # More calibration data
    "batch_size": 2,  # Faster on 48GB VRAM
    "seqlen": 2048,
    "low_gpu_mem_usage": False,  # Keep on GPU for speed
    "enable_torch_compile": True,  # JIT acceleration
    "quant_nontext_module": False,  # Keep Vision Tower in FP16 (Crucial for VLM accuracy)
    # "layer_config": layer_config
}

# %%
def push_to_hub(local_dir, repo_name, token):
    full_repo_id = f"{HF_USER}/{repo_name}"
    print(f"\n[Hub] Pushing {local_dir} to {full_repo_id}...")
    try:
        api = HfApi()
        create_repo(full_repo_id, repo_type="model", exist_ok=True, private=False, token=token)
        api.upload_folder(folder_path=local_dir, repo_id=full_repo_id, repo_type="model", token=token)
        print(f"[Hub] ✅ Successfully uploaded: https://huggingface.co/{full_repo_id}")
    except Exception as e:
        print(f"[Hub] ❌ Error uploading: {e}")

# %%
ar = AutoRound(
    model=model,
    tokenizer=tokenizer,
    processor=processor,
    scheme="W4A16",
    **TUNING_CONFIG,
)
# Out:
# 2026-06-07 14:36:48 INFO entry.py L587: Using MLLM mode for multimodal model.

# %%
# SINGLE CALL to save all 3 formats to the same output directory
# The files will exist side-by-side or merged in this folder.
ar.quantize_and_save(
    OUTPUT_BASE_DIR, format="auto_round", inplace=True
)
# Out:
# 2026-06-07 14:36:54 WARNING logging.py L340: some layers are skipped quantization (shape not divisible by 32):
# [transformers] `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# 2026-06-07 14:36:54 WARNING special_model_handler.py L383: Applying a monkey patch to Gemma4 to reduce RAM usage. This patch has only been validated with limited Transformers versions. Proceed with caution.
# 2026-06-07 14:36:54 INFO data_driven.py L662: start to cache block inputs
# 2026-06-07 14:36:54 INFO mllm.py L83: Using MLLM template: gemma4
# 2026-06-07 14:36:54 INFO calib_dataset.py L977: Preprocessing calibration dataset in a subprocess to avoid memory leaks...
# 2026-06-07 14:37:29 WARNING logging.py L340: Please note that 'shared_kv_states' key is not currently used in quantization fine-tuning.
# 2026-06-07 14:37:48 INFO data_driven.py L685: caching done
# Quantizing model.language_model.layers.0:   0%|          | 0/35 [00:01<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:869: UserWarning: Memory Efficient attention defaults to a non-deterministic algorithm. To explicitly enable determinism call torch.use_deterministic_algorithms(True, warn_only=False). (Triggered internally at /pytorch/aten/src/ATen/native/transformers/cuda/attention_backward.cu:900.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# quantized 9/9 layers in the block, loss iter 0: 0.001801 -> iter 753: 0.000583
# 2026-06-07 14:38:22 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.47GB
# Quantizing model.language_model.layers.1:   3%|▎         | 1/35 [00:34<19:22, 34.20s/it]quantized 9/9 layers in the block, loss iter 0: 0.002719 -> iter 781: 0.000621
# 2026-06-07 14:38:40 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.52GB
# Quantizing model.language_model.layers.2:   6%|▌         | 2/35 [00:51<13:30, 24.55s/it]quantized 9/9 layers in the block, loss iter 0: 0.007777 -> iter 648: 0.002736
# 2026-06-07 14:38:57 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.3:   9%|▊         | 3/35 [01:09<11:21, 21.28s/it]quantized 9/9 layers in the block, loss iter 0: 0.018055 -> iter 709: 0.006524
# 2026-06-07 14:39:15 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.4:  11%|█▏        | 4/35 [01:27<10:17, 19.91s/it]/usr/local/lib/python3.12/dist-packages/torch/_inductor/compile_fx.py:322: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# quantized 9/9 layers in the block, loss iter 0: 0.030428 -> iter 665: 0.010842
# 2026-06-07 14:39:53 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.5:  14%|█▍        | 5/35 [02:05<13:16, 26.54s/it]quantized 9/9 layers in the block, loss iter 0: 0.035828 -> iter 556: 0.011183
# 2026-06-07 14:40:11 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.6:  17%|█▋        | 6/35 [02:23<11:22, 23.53s/it]quantized 9/9 layers in the block, loss iter 0: 0.047214 -> iter 594: 0.013670
# 2026-06-07 14:40:29 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.7:  20%|██        | 7/35 [02:40<10:05, 21.63s/it]quantized 9/9 layers in the block, loss iter 0: 0.102321 -> iter 440: 0.029917
# 2026-06-07 14:40:47 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.8:  23%|██▎       | 8/35 [02:58<09:11, 20.41s/it]quantized 9/9 layers in the block, loss iter 0: 0.183911 -> iter 580: 0.049858
# 2026-06-07 14:41:04 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.9:  26%|██▌       | 9/35 [03:16<08:28, 19.56s/it]quantized 9/9 layers in the block, loss iter 0: 0.267148 -> iter 696: 0.072664
# 2026-06-07 14:41:32 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.10:  29%|██▊       | 10/35 [03:44<09:15, 22.20s/it]quantized 9/9 layers in the block, loss iter 0: 0.210338 -> iter 748: 0.081460
# 2026-06-07 14:41:50 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.11:  31%|███▏      | 11/35 [04:01<08:18, 20.76s/it]quantized 9/9 layers in the block, loss iter 0: 0.259026 -> iter 747: 0.113542
# 2026-06-07 14:42:07 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.12:  34%|███▍      | 12/35 [04:19<07:32, 19.66s/it]quantized 9/9 layers in the block, loss iter 0: 0.158168 -> iter 542: 0.063552
# 2026-06-07 14:42:25 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.13:  37%|███▋      | 13/35 [04:36<06:59, 19.06s/it]quantized 9/9 layers in the block, loss iter 0: 0.140599 -> iter 795: 0.057630
# 2026-06-07 14:42:52 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.14:  40%|████      | 14/35 [05:03<07:29, 21.39s/it]quantized 9/9 layers in the block, loss iter 0: 0.157124 -> iter 763: 0.036833
# 2026-06-07 14:43:28 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.15:  43%|████▎     | 15/35 [05:40<08:38, 25.92s/it]quantized 7/7 layers in the block, loss iter 0: 0.295510 -> iter 757: 0.107198
# 2026-06-07 14:43:59 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.16:  46%|████▌     | 16/35 [06:10<08:39, 27.36s/it]quantized 7/7 layers in the block, loss iter 0: 0.106484 -> iter 285: 0.070982
# 2026-06-07 14:44:21 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.17:  49%|████▊     | 17/35 [06:33<07:45, 25.84s/it]quantized 7/7 layers in the block, loss iter 0: 0.227530 -> iter 427: 0.106154
# 2026-06-07 14:44:43 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.18:  51%|█████▏    | 18/35 [06:55<07:00, 24.71s/it]quantized 7/7 layers in the block, loss iter 0: 0.255171 -> iter 482: 0.112822
# 2026-06-07 14:45:06 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.19:  54%|█████▍    | 19/35 [07:17<06:24, 24.05s/it]quantized 7/7 layers in the block, loss iter 0: 0.263243 -> iter 589: 0.140650
# 2026-06-07 14:45:44 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.20:  57%|█████▋    | 20/35 [07:56<07:05, 28.38s/it]quantized 7/7 layers in the block, loss iter 0: 0.302463 -> iter 745: 0.165998
# 2026-06-07 14:46:06 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.21:  60%|██████    | 21/35 [08:17<06:09, 26.41s/it]quantized 7/7 layers in the block, loss iter 0: 0.241488 -> iter 576: 0.167048
# 2026-06-07 14:46:28 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.22:  63%|██████▎   | 22/35 [08:39<05:26, 25.09s/it]quantized 7/7 layers in the block, loss iter 0: 0.270119 -> iter 673: 0.152181
# 2026-06-07 14:46:50 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.23:  66%|██████▌   | 23/35 [09:02<04:50, 24.19s/it]quantized 7/7 layers in the block, loss iter 0: 0.290843 -> iter 632: 0.187216
# 2026-06-07 14:47:12 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.24:  69%|██████▊   | 24/35 [09:24<04:18, 23.53s/it]quantized 7/7 layers in the block, loss iter 0: 0.477874 -> iter 781: 0.245650
# 2026-06-07 14:47:44 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.25:  71%|███████▏  | 25/35 [09:55<04:20, 26.01s/it]quantized 7/7 layers in the block, loss iter 0: 0.479902 -> iter 334: 0.268996
# 2026-06-07 14:48:06 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.26:  74%|███████▍  | 26/35 [10:17<03:43, 24.81s/it]quantized 7/7 layers in the block, loss iter 0: 0.414562 -> iter 546: 0.307955
# 2026-06-07 14:48:28 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.27:  77%|███████▋  | 27/35 [10:39<03:11, 23.94s/it]quantized 7/7 layers in the block, loss iter 0: 0.395988 -> iter 223: 0.334927
# 2026-06-07 14:48:50 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.28:  80%|████████  | 28/35 [11:01<02:43, 23.38s/it]quantized 7/7 layers in the block, loss iter 0: 0.517341 -> iter 752: 0.328032
# 2026-06-07 14:49:12 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.29:  83%|████████▎ | 29/35 [11:24<02:18, 23.09s/it]quantized 7/7 layers in the block, loss iter 0: 0.513575 -> iter 149: 0.375405
# 2026-06-07 14:49:45 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.30:  86%|████████▌ | 30/35 [11:56<02:09, 25.94s/it]quantized 7/7 layers in the block, loss iter 0: 0.467064 -> iter 175: 0.387605
# 2026-06-07 14:50:07 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.31:  89%|████████▊ | 31/35 [12:19<01:39, 24.94s/it]quantized 7/7 layers in the block, loss iter 0: 0.452429 -> iter 580: 0.376749
# 2026-06-07 14:50:30 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.32:  91%|█████████▏| 32/35 [12:42<01:12, 24.27s/it]quantized 7/7 layers in the block, loss iter 0: 0.424737 -> iter 760: 0.350986
# 2026-06-07 14:50:53 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.33:  94%|█████████▍| 33/35 [13:04<00:47, 23.74s/it]quantized 7/7 layers in the block, loss iter 0: 0.338055 -> iter 523: 0.261632
# 2026-06-07 14:51:15 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing model.language_model.layers.34:  97%|█████████▋| 34/35 [13:26<00:23, 23.28s/it]quantized 7/7 layers in the block, loss iter 0: 0.029984 -> iter 689: 0.017543
# 2026-06-07 14:51:47 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# Quantizing done: 100%|██████████| 35/35 [13:59<00:00, 24.00s/it]
# 2026-06-07 14:51:48 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# 2026-06-07 14:52:06 INFO shard_writer.py L367: model has been saved to ./AutoRound-e2b-AR/local_model-e2b-AR-w4g128/
# 2026-06-07 14:52:06 INFO data_driven.py L750: quantization tuning time 858.3930690288544
# 2026-06-07 14:52:06 INFO data_driven.py L769: Summary: quantized 275/526 in the model, unquantized layers: lm_head, model.audio_tower.layers.[0-11].feed_forward1.ffw_layer_1.linear, model.audio_tower.layers.[0-11].feed_forward1.ffw_layer_2.linear, model.audio_tower.layers.[0-11].feed_forward2.ffw_layer_1.linear, model.audio_tower.layers.[0-11].feed_forward2.ffw_layer_2.linear, model.audio_tower.layers.[0-11].lconv1d.linear_end.linear, model.audio_tower.layers.[0-11].lconv1d.linear_start.linear, model.audio_tower.layers.[0-11].self_attn.k_proj.linear, model.audio_tower.layers.[0-11].self_attn.post.linear, model.audio_tower.layers.[0-11].self_attn.q_proj.linear, model.audio_tower.layers.[0-11].self_attn.relative_k_proj, model.audio_tower.layers.[0-11].self_attn.v_proj.linear, model.audio_tower.output_proj, model.audio_tower.subsample_conv_projection.input_proj_linear, model.embed_audio.embedding_projection, model.embed_vision.embedding_projection, model.language_model.per_layer_model_projection, model.vision_tower.encoder.layers.[0-15].mlp.down_proj.linear, model.vision_tower.encoder.layers.[0-15].mlp.gate_proj.linear, model.vision_tower.encoder.layers.[0-15].mlp.up_proj.linear, model.vision_tower.encoder.layers.[0-15].self_attn.k_proj.linear, model.vision_tower.encoder.layers.[0-15].self_attn.o_proj.linear, model.vision_tower.encoder.layers.[0-15].self_attn.q_proj.linear, model.vision_tower.encoder.layers.[0-15].self_attn.v_proj.linear, model.vision_tower.patch_embedder.input_proj
# 2026-06-07 14:52:07 INFO utils.py L247: Immediate saving mode: weights already saved by ShardWriter, saving configs only.
# 2026-06-07 14:52:07 INFO device.py L1840: 'peak_ram': 17.47GB, 'peak_vram': 15.75GB
# (Gemma4ForConditionalGeneration(
#    (model): Gemma4Model(
#      (vision_tower): Gemma4VisionModel(
#        (patch_embedder): Gemma4VisionPatchEmbedder(
#          (input_proj): Linear(in_features=768, out_features=768, bias=False)
#        )
#        (encoder): Gemma4VisionEncoder(
#          (rotary_emb): Gemma4VisionRotaryEmbedding()
#          (layers): ModuleList(
#            (0-15): 16 x Gemma4VisionEncoderLayer(
#              (self_attn): Gemma4VisionAttention(
#                (q_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=768, out_features=768, bias=False)
#                )
#                (k_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=768, out_features=768, bias=False)
#                )
#                (v_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=768, out_features=768, bias=False)
#                )
#                (o_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=768, out_features=768, bias=False)
#                )
#                (q_norm): Gemma4RMSNorm()
#                (k_norm): Gemma4RMSNorm()
#                (v_norm): Gemma4RMSNorm()
#              )
#              (mlp): Gemma4VisionMLP(
#                (gate_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=768, out_features=3072, bias=False)
#                )
#                (up_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=768, out_features=3072, bias=False)
#                )
#                (down_proj): Gemma4ClippableLinear(
#                  (linear): Linear(in_features=3072, out_features=768, bias=False)
#                )
#                (act_fn): GELUTanh()
#              )
#              (input_layernorm): Gemma4RMSNorm()
#              (post_attention_layernorm): Gemma4RMSNorm()
#              (pre_feedforward_layernorm): Gemma4RMSNorm()
#              (post_feedforward_layernorm): Gemma4RMSNorm()
#            )
#          )
#        )
#        (pooler): Gemma4VisionPooler()
#      )
#      (language_model): Gemma4TextModel(
#        (embed_tokens): Gemma4TextScaledWordEmbedding(262144, 1536, padding_idx=0)
#        (layers): ModuleList(
#          (0-14): 15 x Gemma4TextDecoderLayer(
#            (self_attn): Gemma4TextAttention(
#              (q_proj): QuantLinear()
#              (q_norm): Gemma4RMSNorm()
#              (k_norm): Gemma4RMSNorm()
#              (v_norm): Gemma4RMSNorm()
#              (k_proj): QuantLinear()
#              (v_proj): QuantLinear()
#              (o_proj): QuantLinear()
#            )
#            (mlp): Gemma4TextMLP(
#              (gate_proj): QuantLinear()
#              (up_proj): QuantLinear()
#              (down_proj): QuantLinear()
#              (act_fn): GELUTanh()
#            )
#            (input_layernorm): Gemma4RMSNorm()
#            (post_attention_layernorm): Gemma4RMSNorm()
#            (pre_feedforward_layernorm): Gemma4RMSNorm()
#            (post_feedforward_layernorm): Gemma4RMSNorm()
#            (act_fn): GELUTanh()
#            (per_layer_input_gate): QuantLinear()
#            (per_layer_projection): QuantLinear()
#            (post_per_layer_input_norm): Gemma4RMSNorm()
#          )
#          (15-34): 20 x Gemma4TextDecoderLayer(
#            (self_attn): Gemma4TextAttention(
#              (q_proj): QuantLinear()
#              (q_norm): Gemma4RMSNorm()
#              (o_proj): QuantLinear()
#            )
#            (mlp): Gemma4TextMLP(
#              (gate_proj): QuantLinear()
#              (up_proj): QuantLinear()
#              (down_proj): QuantLinear()
#              (act_fn): GELUTanh()
#            )
#            (input_layernorm): Gemma4RMSNorm()
#            (post_attention_layernorm): Gemma4RMSNorm()
#            (pre_feedforward_layernorm): Gemma4RMSNorm()
#            (post_feedforward_layernorm): Gemma4RMSNorm()
#            (act_fn): GELUTanh()
#            (per_layer_input_gate): QuantLinear()
#            (per_layer_projection): QuantLinear()
#            (post_per_layer_input_norm): Gemma4RMSNorm()
#          )
#        )
#        (norm): Gemma4RMSNorm()
#        (rotary_emb): Gemma4TextRotaryEmbedding()
#        (embed_tokens_per_layer): Gemma4TextScaledWordEmbedding(262144, 8960, padding_idx=0)
#        (per_layer_model_projection): Linear(in_features=1536, out_features=8960, bias=False)
#        (per_layer_projection_norm): Gemma4RMSNorm()
#      )
#      (audio_tower): Gemma4AudioModel(
#        (subsample_conv_projection): Gemma4AudioSubSampleConvProjection(
#          (layer0): Gemma4AudioSubSampleConvProjectionLayer(
#            (conv): Conv2d(1, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (norm): LayerNorm((128,), eps=1e-06, elementwise_affine=True)
#            (act): ReLU()
#          )
#          (layer1): Gemma4AudioSubSampleConvProjectionLayer(
#            (conv): Conv2d(128, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (norm): LayerNorm((32,), eps=1e-06, elementwise_affine=True)
#            (act): ReLU()
#          )
#          (input_proj_linear): Linear(in_features=1024, out_features=1024, bias=False)
#        )
#        (rel_pos_enc): Gemma4AudioRelPositionalEncoding()
#        (layers): ModuleList(
#          (0-11): 12 x Gemma4AudioLayer(
#            (feed_forward1): Gemma4AudioFeedForward(
#              (ffw_layer_1): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=4096, bias=False)
#              )
#              (ffw_layer_2): Gemma4ClippableLinear(
#                (linear): Linear(in_features=4096, out_features=1024, bias=False)
#              )
#              (pre_layer_norm): Gemma4RMSNorm()
#              (post_layer_norm): Gemma4RMSNorm()
#              (act_fn): SiLUActivation()
#            )
#            (feed_forward2): Gemma4AudioFeedForward(
#              (ffw_layer_1): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=4096, bias=False)
#              )
#              (ffw_layer_2): Gemma4ClippableLinear(
#                (linear): Linear(in_features=4096, out_features=1024, bias=False)
#              )
#              (pre_layer_norm): Gemma4RMSNorm()
#              (post_layer_norm): Gemma4RMSNorm()
#              (act_fn): SiLUActivation()
#            )
#            (self_attn): Gemma4AudioAttention(
#              (q_proj): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=1024, bias=False)
#              )
#              (k_proj): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=1024, bias=False)
#              )
#              (v_proj): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=1024, bias=False)
#              )
#              (post): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=1024, bias=False)
#              )
#              (relative_k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#            )
#            (lconv1d): Gemma4AudioLightConv1d(
#              (linear_start): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=2048, bias=False)
#              )
#              (linear_end): Gemma4ClippableLinear(
#                (linear): Linear(in_features=1024, out_features=1024, bias=False)
#              )
#              (depthwise_conv1d): Gemma4AudioCausalConv1d(1024, 1024, kernel_size=(5,), stride=(1,), groups=1024, bias=False)
#              (pre_layer_norm): Gemma4RMSNorm()
#              (conv_norm): Gemma4RMSNorm()
#              (act_fn): SiLUActivation()
#            )
#            (norm_pre_attn): Gemma4RMSNorm()
#            (norm_post_attn): Gemma4RMSNorm()
#            (norm_out): Gemma4RMSNorm()
#          )
#        )
#        (output_proj): Linear(in_features=1024, out_features=1536, bias=True)
#      )
#      (embed_vision): Gemma4MultimodalEmbedder(
#        (embedding_projection): Linear(in_features=768, out_features=1536, bias=False)
#        (embedding_pre_projection_norm): Gemma4RMSNorm()
#      )
#      (embed_audio): Gemma4MultimodalEmbedder(
#        (embedding_projection): Linear(in_features=1536, out_features=1536, bias=False)
#        (embedding_pre_projection_norm): Gemma4RMSNorm()
#      )
#    )
#    (lm_head): Linear(in_features=1536, out_features=262144, bias=False)
#  ),
#  './AutoRound-e2b-AR/local_model-e2b-AR-w4g128')

# %%
base_name = MODEL_ID.split("/")[-1]
hf_token = get_token()

# %%
if hf_token:
    # Push auto_round format
    push_to_hub(
        os.path.join(OUTPUT_BASE_DIR, "local_model-e2b-AR-w4g128"),
        f"{base_name}-W4A16-AutoRound",
        hf_token
    )
    
else:
    print("No Hugging Face token found. Skipping upload to hub.")
# Out:
# [Hub] Pushing ./AutoRound-e2b-AR/local_model-e2b-AR-w4g128 to Vishva007/gemma-4-E2B-it-W4A16-AutoRound...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# [Hub] ✅ Successfully uploaded: https://huggingface.co/Vishva007/gemma-4-E2B-it-W4A16-AutoRound
