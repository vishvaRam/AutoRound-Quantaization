# %%
# !pip install --upgrade "transformers<5.0"

# %%
# !pip install git+https://github.com/intel/auto-round.git

# %%
import os
import torch
from auto_round import AutoRound
from huggingface_hub import HfApi, create_repo, notebook_login, get_token
from transformers import Qwen3VLForConditionalGeneration, AutoProcessor

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"CUDA Version: {torch.version.cuda}")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
# Out:
# PyTorch Version: 2.8.0+cu126
# CUDA Available: True
# CUDA Version: 12.6
# GPU Name: NVIDIA GeForce RTX 3090
# VRAM: 23.6 GB

# %%
MODEL_ID = "Qwen/Qwen3-VL-4B-Instruct"
HF_USER = "Vishva007"
OUTPUT_BASE_DIR = "./AutoRound"

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
TUNING_CONFIG = {
    "group_size": 128,
    "sym": True,
    "iters": 800,  # High accuracy (Production grade)
    "nsamples": 512,  # More calibration data
    "batch_size": 2,  # Faster on 48GB VRAM
    "seqlen": 2048,
    "low_gpu_mem_usage": False,  # Keep on GPU for speed
    "enable_torch_compile": True,  # JIT acceleration
    "quant_nontext_module": False,  # Keep Vision Tower in BF16 (Crucial for VLM accuracy)
}

# %%
def push_to_hub(local_dir, repo_name, token):
    """Creates repo and uploads folder to Hugging Face."""
    full_repo_id = f"{HF_USER}/{repo_name}"
    print(f"\n[Hub] Pushing {local_dir} to {full_repo_id}...")

    try:
        api = HfApi()
        create_repo(
            full_repo_id, repo_type="model", exist_ok=True, private=False, token=token
        )

        api.upload_folder(
            folder_path=local_dir, repo_id=full_repo_id, repo_type="model", token=token
        )
        print(f"[Hub] ✅ Successfully uploaded: https://huggingface.co/{full_repo_id}")
    except Exception as e:
        print(f"[Hub] ❌ Error uploading: {e}")

# %%
model = Qwen3VLForConditionalGeneration.from_pretrained(
    MODEL_ID, dtype=torch.float16, device_map="auto"
)
processor = AutoProcessor.from_pretrained(MODEL_ID)

tokenizer = processor.tokenizer
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.91G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/269 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/390 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# video_preprocessor_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]

# %%
ar = AutoRound(
    model=model,
    tokenizer=tokenizer,
    processor=processor,
    scheme="W4A16",
    model_dtype="fp16",
    **TUNING_CONFIG,
)
# Out:
# 2026-02-07 17:40:17 INFO autoround.py L165: using MLLM mode for multimodal model.
# 2026-02-07 17:40:18 INFO base.py L486: using torch.float16 for quantization tuning

# %%
# SINGLE CALL to save all 3 formats to the same output directory
# The files will exist side-by-side or merged in this folder.
ar.quantize_and_save(
    OUTPUT_BASE_DIR, format="auto_gptq,auto_awq,auto_round", inplace=True
)
# Out:
# 2026-02-07 17:40:20 WARNING base.py L1639: `low_cpu_mem_usage` is only supported when `immediate_packing` is True. Setting `low_cpu_mem_usage` to False.
# 2026-02-07 17:40:20 INFO base.py L1739: start to cache block inputs
# README.md:   0%|          | 0.00/373 [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/921 [00:00<?, ?B/s]
# data/train-00000-of-00001-4746b8785c874c(…):   0%|          | 0.00/33.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/1216 [00:00<?, ? examples/s]
# cache block inputs:   0%|          | 0/512 [00:00<?, ?it/s]/opt/conda/lib/python3.11/site-packages/transformers/models/qwen3_vl/modeling_qwen3_vl.py:328: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   freqs = (inv_freq_expanded.float() @ position_ids_expanded.float()).transpose(2, 3)
# cache block inputs: 100%|██████████| 512/512 [00:08<00:00, 60.85it/s]
# 2026-02-07 17:41:20 INFO base.py L1754: caching done
# Quantizing model.language_model.layers.0:   0%|          | 0/36 [00:00<?, ?it/s]/tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:558: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg6_1, (2560, 4096), (1, 2560), 0), out=buf2)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:569: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg8_1, (2560, 1024), (1, 2560), 0), out=buf5)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:579: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg10_1, (2560, 1024), (1, 2560), 0), out=buf8)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:592: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf12, (4096, 4096), (4096, 1), 0), reinterpret_tensor(arg11_1, (4096, 2560), (1, 4096), 0), out=buf17)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:602: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf19, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg13_1, (2560, 9728), (1, 2560), 0), out=buf20)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:606: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf19, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg14_1, (2560, 9728), (1, 2560), 0), out=buf21)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:615: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf22, (4096, 9728), (9728, 1), 0), reinterpret_tensor(arg15_1, (9728, 2560), (1, 9728), 0), out=buf23)
# /tmp/torchinductor_root/ae/cae353vwoktbgimcg7yje7q4yshaw6n4rxjrqv6ulsdse42arynb.py:1095: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf5, (4096, 2560), (2560, 1), 0), reinterpret_tensor(buf6, (2560, 4096), (1, 2560), 0), out=buf7)
# /tmp/torchinductor_root/ae/cae353vwoktbgimcg7yje7q4yshaw6n4rxjrqv6ulsdse42arynb.py:1119: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf5, (4096, 2560), (2560, 1), 0), reinterpret_tensor(buf14, (2560, 1024), (1, 2560), 0), out=buf15)
# /tmp/torchinductor_root/ae/cae353vwoktbgimcg7yje7q4yshaw6n4rxjrqv6ulsdse42arynb.py:1143: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf5, (4096, 2560), (2560, 1), 0), reinterpret_tensor(buf22, (2560, 1024), (1, 2560), 0), out=buf23)
# /tmp/torchinductor_root/ae/cae353vwoktbgimcg7yje7q4yshaw6n4rxjrqv6ulsdse42arynb.py:1177: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(bu
UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf8, (9728, 4096), (1, 9728), 0), view_22, out=buf9)
# /tmp/torchinductor_root/kz/ckzspy3ltmhgo2ozvcfemnppahb7tkpg4zw33fs4tq6dhlsok7dc.py:1197: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf17, (9728, 4096), (1, 9728), 0), view_22, out=buf18)
# /opt/conda/lib/python3.11/site-packages/torch/autograd/graph.py:829: UserWarning: Flash Attention defaults to a non-deterministic algorithm. To explicitly enable determinism call torch.use_deterministic_algorithms(True, warn_only=False). (Triggered internally at /pytorch/aten/src/ATen/native/transformers/cuda/attention_backward.cu:110.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:558: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg6_1, (2560, 4096), (1, 2560), 0), out=buf2)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:569: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg8_1, (2560, 1024), (1, 2560), 0), out=buf5)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:579: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg10_1, (2560, 1024), (1, 2560), 0), out=buf8)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:592: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf12, (4096, 4096), (4096, 1), 0), reinterpret_tensor(arg11_1, (4096, 2560), (1, 4096), 0), out=buf17)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:602: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf19, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg13_1, (2560, 9728), (1, 2560), 0), out=buf20)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:606: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf19, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg14_1, (2560, 9728), (1, 2560), 0), out=buf21)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:615: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf22, (4096, 9728), (9728, 1), 0), reinterpret_tensor(arg15_1, (9728, 2560), (1, 9728), 0), out=buf23)
# quantized 7/7 layers in the block, loss iter 0: 0.000157 -> iter 299: 0.000038,'peak_ram': 21.56GB, 'peak_vram': 18.14GB
# Quantizing model.language_model.layers.1:   3%|▎         | 1/36 [01:23<48:56, 83.89s/it]/tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:558: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf1, (4096, 2560), (2560, 1), 0), reinterpret_tensor(arg6_1, (2560, 4096), (1, 2560), 0), out=buf2)
# /tmp/torchinductor_root/t2/ct2ja2eotoommcjcmsbjb356jr3qdq4vjqqrny4ufohsdeg7d7ir.py:569: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(bu
UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#results-reproducibility (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:233.)
#   extern_kernels.mm(reinterpret_tensor(buf22, (4096, 9728), (9728, 1), 0), reinterpret_tensor(arg15_1, (9728, 2560), (1, 9728), 0), out=buf23)
# quantized 7/7 layers in the block, loss iter 0: 0.000365 -> iter 731: 0.000042,'peak_ram': 21.56GB, 'peak_vram': 18.35GB
# Quantizing model.language_model.layers.2:   6%|▌         | 2/36 [02:08<34:20, 60.61s/it]quantized 7/7 layers in the block, loss iter 0: 0.000587 -> iter 778: 0.000095,'peak_ram': 21.56GB, 'peak_vram': 18.53GB
# Quantizing model.language_model.layers.3:   8%|▊         | 3/36 [02:52<29:07, 52.94s/it]quantized 7/7 layers in the block, loss iter 0: 0.000901 -> iter 595: 0.000189,'peak_ram': 21.56GB, 'peak_vram': 18.53GB
# Quantizing model.language_model.layers.4:  11%|█         | 4/36 [03:36<26:22, 49.45s/it]quantized 7/7 layers in the block, loss iter 0: 0.001689 -> iter 652: 0.000417,'peak_ram': 21.56GB, 'peak_vram': 18.56GB
# Quantizing model.language_model.layers.5:  14%|█▍        | 5/36 [04:20<24:34, 47.56s/it]quantized 7/7 layers in the block, loss iter 0: 0.002444 -> iter 761: 0.000688,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.6:  17%|█▋        | 6/36 [05:04<23:10, 46.35s/it]quantized 7/7 layers in the block, loss iter 0: 0.044765 -> iter 797: 0.002436,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.7:  19%|█▉        | 7/36 [05:48<22:01, 45.58s/it]quantized 7/7 layers in the block, loss iter 0: 0.039558 -> iter 736: 0.002489,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.8:  22%|██▏       | 8/36 [06:32<21:01, 45.06s/it]quantized 7/7 layers in the block, loss iter 0: 0.009036 -> iter 680: 0.003535,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.9:  25%|██▌       | 9/36 [07:16<20:08, 44.74s/it]quantized 7/7 layers in the block, loss iter 0: 0.008913 -> iter 523: 0.003857,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.10:  28%|██▊       | 10/36 [08:00<19:18, 44.54s/it]quantized 7/7 layers in the block, loss iter 0: 0.008157 -> iter 748: 0.002761,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.11:  31%|███       | 11/36 [08:44<18:29, 44.39s/it]quantized 7/7 layers in the block, loss iter 0: 0.010210 -> iter 747: 0.003272,'peak_ram': 21.56GB, 'peak_vram': 18.64GB
# Quantizing model.language_model.layers.12:  33%|███▎      | 12/36 [09:28<17:42, 44.29s/it]quantized 7/7 layers in the block, loss iter 0: 0.009320 -> iter 715: 0.004843,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.13:  36%|███▌      | 13/36 [10:12<16:57, 44.23s/it]quantized 7/7 layers in the block, loss iter 0: 0.011192 -> iter 543: 0.005633,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.14:  39%|███▉      | 14/36 [10:57<16:14, 44.30s/it]quantized 7/7 layers in the block, loss iter 0: 0.010611 -> iter 103: 0.005477,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.15:  42%|████▏     | 15/36 [11:41<15:29, 44.25s/it]quantized 7/7 layers in the block, loss iter 0: 0.012608 -> iter 304: 0.007203,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.16:  44%|████▍     | 16/36 [12:25<14:43, 44.20s/it]quantized 7/7 layers in the block, loss iter 0: 0.046214 -> iter 665: 0.015460,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.17:  47%|████▋     | 17/36 [13:09<14:01, 44.28s/it]quantized 7/7 layers in the block, loss iter 0: 0.034242 -> iter 634: 0.016206,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.18:  50%|█████     | 18/36 [13:53<13:16, 44.27s/it]quantized 7/7 layers in the block, loss iter 0: 0.028035 -> iter 595: 0.015637,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.19:  53%|█████▎    | 19/36 [14:38<12:32, 44.25s/it]quantized 7/7 layers in the block, loss iter 0: 0.032849 -> iter 303: 0.019942,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.20:  56%|█████▌    | 20/36 [15:22<11:49, 44.33s/it]quantized 7/7 layers in the block, loss iter 0: 0.046264 -> iter 378: 0.024423,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.21:  58%|█████▊    | 21/36 [16:07<11:05, 44.37s/it]quantized 7/7 layers in the block, loss iter 0: 0.038764 -> iter 315: 0.025959,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.22:  61%|██████    | 22/36 [16:51<10:21, 44.41s/it]quantized 7/7 layers in the block, loss iter 0: 2.268247 -> iter 673: 0.032841,'peak_ram': 21.56GB, 'peak_vram': 18.66GB
# Quantizing model.language_model.layers.23:  64%|██████▍   | 23/36 [17:36<09:37, 44.42s/it]quantized 7/7 layers in the block, loss iter 0: 7.622901 -> iter 602: 0.041683,'peak_ram': 21.56GB, 'peak_vram': 18.73GB
# Quantizing model.language_model.layers.24:  67%|██████▋   | 24/36 [18:20<08:53, 44.44s/it]quantized 7/7 layers in the block, loss iter 0: 0.145169 -> iter 519: 0.052971,'peak_ram': 21.56GB, 'peak_vram': 18.73GB
# Quantizing model.language_model.layers.25:  69%|██████▉   | 25/36 [19:04<08:08, 44.42s/it]quantized 7/7 layers in the block, loss iter 0: 0.229012 -> iter 412: 0.065741,'peak_ram': 21.56GB, 'peak_vram': 18.73GB
# Quantizing model.language_model.layers.26:  72%|███████▏  | 26/36 [19:49<07:23, 44.31s/it]quantized 7/7 layers in the block, loss iter 0: 2.027864 -> iter 696: 0.073175,'peak_ram': 21.56GB, 'peak_vram': 18.73GB
# Quantizing model.language_model.layers.27:  75%|███████▌  | 27/36 [20:33<06:38, 44.26s/it]quantized 7/7 layers in the block, loss iter 0: 14.510841 -> iter 785: 0.100308,'peak_ram': 21.56GB, 'peak_vram': 18.73GB
# Quantizing model.language_model.layers.28:  78%|███████▊  | 28/36 [21:17<05:53, 44.24s/it]quantized 7/7 layers in the block, loss iter 0: 3.717844 -> iter 265: 0.128790,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.29:  81%|████████  | 29/36 [22:01<05:09, 44.21s/it]quantized 7/7 layers in the block, loss iter 0: 0.640639 -> iter 143: 0.158080,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.30:  83%|████████▎ | 30/36 [22:45<04:25, 44.20s/it]quantized 7/7 layers in the block, loss iter 0: 0.405320 -> iter 70: 0.217811,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.31:  86%|████████▌ | 31/36 [23:29<03:40, 44.16s/it]quantized 7/7 layers in the block, loss iter 0: 1.012783 -> iter 414: 0.279995,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.32:  89%|████████▉ | 32/36 [24:14<02:57, 44.27s/it]quantized 7/7 layers in the block, loss iter 0: 0.956821 -> iter 576: 0.323339,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.33:  92%|█████████▏| 33/36 [24:58<02:13, 44.36s/it]quantized 7/7 layers in the block, loss iter 0: 1.045335 -> iter 617: 0.468025,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.34:  94%|█████████▍| 34/36 [25:43<01:28, 44.43s/it]quantized 7/7 layers in the block, loss iter 0: 1.965215 -> iter 521: 0.597516,'peak_ram': 21.56GB, 'peak_vram': 18.77GB
# Quantizing model.language_model.layers.35:  97%|█████████▋| 35/36 [26:28<00:44, 44.49s/it]quantized 7/7 layers in the block, loss iter 0: 5.502062 -> iter 548: 1.222093,'peak_ram': 21.56GB, 'peak_vram': 18.82GB
# Quantizing done: 100%|██████████| 36/36 [27:13<00:00, 45.37s/it]
# 2026-02-07 18:08:33 INFO device.py L1468:  'peak_ram': 21.56GB, 'peak_vram': 18.82GB
# 2026-02-07 18:08:33 INFO base.py L1802: quantization tuning time 1693.1146275997162
# 2026-02-07 18:08:33 INFO base.py L1820: Summary: quantized 252/357 in the model,  ['model.visual.blocks.0.attn.qkv', 'model.visual.blocks.0.attn.proj', 'model.visual.blocks.0.mlp.linear_fc1', 'model.visual.blocks.0.mlp.linear_fc2', 'model.visual.blocks.1.attn.qkv', 'model.visual.blocks.1.attn.proj', 'model.visual.blocks.1.mlp.linear_fc1', 'model.visual.blocks.1.mlp.linear_fc2', 'model.visual.blocks.2.attn.qkv', 'model.visual.blocks.2.attn.proj', 'model.visual.blocks.2.mlp.linear_fc
fc1', 'model.visual.blocks.19.mlp.linear_fc2', 'model.visual.blocks.20.attn.qkv', 'model.visual.blocks.20.attn.proj', 'model.visual.blocks.20.mlp.linear_fc1', 'model.visual.blocks.20.mlp.linear_fc2', 'model.visual.blocks.21.attn.qkv', 'model.visual.blocks.21.attn.proj', 'model.visual.blocks.21.mlp.linear_fc1', 'model.visual.blocks.21.mlp.linear_fc2', 'model.visual.blocks.22.attn.qkv', 'model.visual.blocks.22.attn.proj', 'model.visual.blocks.22.mlp.linear_fc1', 'model.visual.blocks.22.mlp.linear_fc2', 'model.visual.blocks.23.attn.qkv', 'model.visual.blocks.23.attn.proj', 'model.visual.blocks.23.mlp.linear_fc1', 'model.visual.blocks.23.mlp.linear_fc2', 'model.visual.merger.linear_fc1', 'model.visual.merger.linear_fc2', 'model.visual.deepstack_merger_list.0.linear_fc1', 'model.visual.deepstack_merger_list.0.linear_fc2', 'model.visual.deepstack_merger_list.1.linear_fc1', 'model.visual.deepstack_merger_list.1.linear_fc2', 'model.visual ...
# packing model.language_model.layers.35.mlp.down_proj: 100%|██████████| 252/252 [00:03<00:00, 65.65it/s]
# 2026-02-07 18:08:55 INFO export.py L162: Saving quantized model to auto_awq format
# packing model.language_model.layers.35.mlp.down_proj: 100%|██████████| 252/252 [00:03<00:00, 70.61it/s]
# packing model.language_model.layers.35.mlp.down_proj: 100%|██████████| 252/252 [00:03<00:00, 76.14it/s]
# 2026-02-07 18:09:35 INFO device.py L1468:  'peak_ram': 21.56GB, 'peak_vram': 18.82GB
# (Qwen3VLForConditionalGeneration(
#    (model): Qwen3VLModel(
#      (visual): Qwen3VLVisionModel(
#        (patch_embed): Qwen3VLVisionPatchEmbed(
#          (proj): Conv3d(3, 1024, kernel_size=(2, 16, 16), stride=(2, 16, 16))
#        )
#        (pos_embed): Embedding(2304, 1024)
#        (rotary_pos_emb): Qwen3VLVisionRotaryEmbedding()
#        (blocks): ModuleList(
#          (0-23): 24 x Qwen3VLVisionBlock(
#            (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#            (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#            (attn): Qwen3VLVisionAttention(
#              (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#              (proj): Linear(in_features=1024, out_features=1024, bias=True)
#            )
#            (mlp): Qwen3VLVisionMLP(
#              (linear_fc1): Linear(in_features=1024, out_features=4096, bias=True)
#              (linear_fc2): Linear(in_features=4096, out_features=1024, bias=True)
#              (act_fn): GELUTanh()
#            )
#          )
#        )
#        (merger): Qwen3VLVisionPatchMerger(
#          (norm): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#          (linear_fc1): Linear(in_features=4096, out_features=4096, bias=True)
#          (act_fn): GELU(approximate='none')
#          (linear_fc2): Linear(in_features=4096, out_features=2560, bias=True)
#        )
#        (deepstack_merger_list): ModuleList(
#          (0-2): 3 x Qwen3VLVisionPatchMerger(
#            (norm): LayerNorm((4096,), eps=1e-06, elementwise_affine=True)
#            (linear_fc1): Linear(in_features=4096, out_features=4096, bias=True)
#            (act_fn): GELU(approximate='none')
#            (linear_fc2): Linear(in_features=4096, out_features=2560, bias=True)
#          )
#        )
#      )
#      (language_model): Qwen3VLTextModel(
#        (embed_tokens): Embedding(151936, 2560)
#        (layers): ModuleList(
#          (0-35): 36 x Qwen3VLTextDecoderLayer(
#            (self_attn): Qwen3VLTextAttention(
#              (q_proj): QuantLinear()
#              (k_proj): QuantLinear()
#              (v_proj): QuantLinear()
#              (o_proj): QuantLinear()
#              (q_norm): Qwen3VLTextRMSNorm((128,), eps=1e-06)
#              (k_norm): Qwen3VLTextRMSNorm((128,), eps=1e-06)
#            )
#            (mlp): Qwen3VLTextMLP(
#              (gate_proj): QuantLinear()
#              (up_proj): QuantLinear()
#              (down_proj): QuantLinear()
#              (act_fn): SiLUActivation()
#            )
#            (input_layernorm): Qwen3VLTextRMSNorm((2560,), eps=1e-06)
#            (post_attention_layernorm): Qwen3VLTextRMSNorm((2560,), eps=1e-06)
#          )
#        )
#        (norm): Qwen3VLTextRMSNorm((2560,), eps=1e-06)
#        (rotary_emb): Qwen3VLTextRotaryEmbedding()
#      )
#    )
#    (lm_head): Linear(in_features=2560, out_features=151936, bias=False)
#  ),
#  ['./AutoRound/auto-gptq',
#   './AutoRound/auto-awq',
#   './AutoRound/auto-round-auto-gptq'])

# %%
base_name = MODEL_ID.split("/")[-1]
hf_token = get_token()

# %%
path_autoround = os.path.join(OUTPUT_BASE_DIR, "auto-round-auto-gptq")
path_gptq = os.path.join(OUTPUT_BASE_DIR, "auto-gptq")
path_awq = os.path.join(OUTPUT_BASE_DIR, "auto-awq")

# %%
if hf_token:
    # 1. AutoRound Repo
    # Verify path exists before uploading
    if os.path.exists(path_autoround):
        push_to_hub(path_autoround, f"{base_name}-W4A16-AutoRound", hf_token)
    else:
        print(f"⚠️ Could not find AutoRound output at {path_autoround}")

    # 2. GPTQ Repo
    if os.path.exists(path_gptq):
        push_to_hub(path_gptq, f"{base_name}-W4A16-AutoRound-GPTQ", hf_token)
    else:
        print(f"⚠️ Could not find GPTQ output at {path_gptq}")

    # 3. AWQ Repo
    if os.path.exists(path_awq):
        push_to_hub(path_awq, f"{base_name}-W4A16-AutoRound-AWQ", hf_token)
    else:
        print(f"⚠️ Could not find AWQ output at {path_awq}")
# Out:
# [Hub] Pushing ./AutoRound/auto-round-auto-gptq to Vishva007/Qwen3-VL-4B-Instruct-W4A16-AutoRound...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# [Hub] ✅ Successfully uploaded: https://huggingface.co/Vishva007/Qwen3-VL-4B-Instruct-W4A16-AutoRound
#
# [Hub] Pushing ./AutoRound/auto-gptq to Vishva007/Qwen3-VL-4B-Instruct-W4A16-AutoRound-GPTQ...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# [Hub] ✅ Successfully uploaded: https://huggingface.co/Vishva007/Qwen3-VL-4B-Instruct-W4A16-AutoRound-GPTQ
#
# [Hub] Pushing ./AutoRound/auto-awq to Vishva007/Qwen3-VL-4B-Instruct-W4A16-AutoRound-AWQ...
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# [Hub] ✅ Successfully uploaded: https://huggingface.co/Vishva007/Qwen3-VL-4B-Instruct-W4A16-AutoRound-AWQ
